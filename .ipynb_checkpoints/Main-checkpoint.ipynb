# %% [markdown]
# ### Import Libraries

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Dataframe settings
pd.set_option('display.max_rows', 500, 'display.float_format', '{:.2f}'.format)

# %% [markdown]
# ### Import data

# %%
# Import dataset
df_brancher = pd.read_csv("Data/arbejdsmarkedsanalyse_brancher.csv", sep=';', decimal=",", encoding='iso8859_10')
df_personer = pd.read_csv("Data/arbejdsmarkedsanalyse_koen_alder.csv", sep=';', decimal=",", encoding='iso8859_10')

# %% [markdown]
# ### Descriptive Statistics - "Brancher"

# %%
# Show data preview
df_brancher.head(3)
# Out:
#    Field Values Index                                      Ordforklaring  \
# 0               49.82  Spørgsmål: Hvor ofte oplever du, at du har nok...
# 1               59.25  Spørgsmål: Hvor ofte oplever du, at du har nok...
# 2               89.95  Spørgsmål: Hvor ofte oplever du, at du har nok...
#
#     Akse  Farveskala  Field Values Index (Fixed)  \
# 0  Score       -5.06                       54.88
# 1  Score        4.36                       54.88
# 2  Score       35.07                       54.88
#
#   Navigation - Arbejdsmiljøprofiler  Score (Indekseret score) (gennemsnit)  \
# 0              Arbejdsmiljøprofiler                                  52.18
# 1              Arbejdsmiljøprofiler                                  52.18
# 2              Arbejdsmiljøprofiler                                  52.18
#
#    Score (Indekseret score) (gennemsnit) (label)  Score (Total) (Fixed)  \
# 0                                           2.61                  -2.61
# 1                                           2.61                  -2.61
# 2                                           2.61                  -2.61
#
#    Gennemsnit  Score (Indekseret score)  Score (Total)  Antpct  Antpers  \
# 0         nan                     53.17            nan     nan      224
# 1         nan                     51.32            nan     nan      388
# 2         nan                     45.30            nan     nan      189
#
#                                       Group  Hoej Score Godt  Kategori10  \
# 0  Bibliotekarer og beskæftigede med kultur                0         nan
# 1                                Bogholdere                0         nan
# 2    Brandmænd, reddere og sikkerhedsvagter                0         nan
#
#   Kategori11  Kategori12  Kategori13  Kategori14  Kategori15  Kategori1  \
# 0        NaN         nan         nan         nan         nan   1. Altid
# 1        NaN         nan         nan         nan         nan   1. Altid
# 2        NaN         nan         nan         nan         nan   1. Altid
#
#   Kategori2       Kategori3     Kategori4   Kategori5 Kategori6  Kategori7  \
# 0   2. Ofte   3. Sommetider   4. Sjældent   5. Aldrig       NaN        nan
# 1   2. Ofte   3. Sommetider   4. Sjældent   5. Aldrig       NaN        nan
# 2   2. Ofte   3. Sommetider   4. Sjældent   5. Aldrig       NaN        nan
#
#    Kategori8  Kategori9 Main Group  Score  Field Values  Mean  \
# 0        nan        nan        Job   2.66         -2.66  2.66
# 1        nan        nan        Job   2.57         -2.57  2.57
# 2        nan        nan        Job   2.26         -2.26  2.26
#
#                     Question Label  \
# 0  Ikke nok tid til arbejdsopgaver
# 1  Ikke nok tid til arbejdsopgaver
# 2  Ikke nok tid til arbejdsopgaver
#
#                                            Sluttekst  \
# 0  I resultaterne præsenteres den gennemsnitlige ...
# 1  I resultaterne præsenteres den gennemsnitlige ...
# 2  I resultaterne præsenteres den gennemsnitlige ...
#
#                                      Spm Formulering  \
# 0  Hvor ofte oplever du, at du har nok tid til di...
# 1  Hvor ofte oplever du, at du har nok tid til di...
# 2  Hvor ofte oplever du, at du har nok tid til di...
#
#                          Topic Label  Type  Year isPsychological
# 0  Kvantitative krav og grænseløshed  kont  2018               1
# 1  Kvantitative krav og grænseløshed  kont  2018               1
# 2  Kvantitative krav og grænseløshed  kont  2018               1

# %%
# Get general info about the dataframe
df_brancher.info()

# Get descriptive statistics
df_brancher.describe(include='all')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8115 entries, 0 to 8114
# Data columns (total 42 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   Field Values Index                             8096 non-null   float64
#  1   Ordforklaring                                  7737 non-null   object
#  2   Akse                                           8096 non-null   object
#  3   Farveskala                                     8096 non-null   float64
#  4   Field Values Index (Fixed)                     8115 non-null   float64
#  5   Navigation - Arbejdsmiljøprofiler              8115 non-null   object
#  6   Score (Indekseret score) (gennemsnit)          8115 non-null   float64
#  7   Score (Indekseret score) (gennemsnit) (label)  8115 non-null   float64
#  8   Score (Total) (Fixed)                          8115 non-null   float64
#  9   Gennemsnit                                     109 non-null    float64
#  10  Score (Indekseret score)                       8096 non-null   float64
#  11  Score (Total)                                  109 non-null    float64
#  12  Antpct                                         3308 non-null   float64
#  13  Antpers                                        8115 non-null   int64
#  14  Group                                          8115 non-null   object
#  15  Hoej Score Godt                                8115 non-null   int64
#  16  Kategori10                                     152 non-null    float64
#  17  Kategori11                                     152 non-null    object
#  18  Kategori12                                     0 non-null      float64
#  19  Kategori13                                     0 non-null      float64
#  20  Kategori14                                     0 non-null      float64
#  21  Kategori15                                     0 non-null      float64
#  22  Kategori1                                      7737 non-null   object
#  23  Kategori2                                      7281 non-null   object
#  24  Kategori3                                      7129 non-null   object
#  25  Kategori4                                      6602 non-null   object
#  26  Kategori5                                      6530 non-null   object
#  27  Kategori6                                      2265 non-null   object
#  28  Kategori7                                      152 non-null    float64
#  29  Kategori8                                      152 non-null    float64
#  30  Kategori9                                      152 non-null    float64
#  31  Main Group                                     8115 non-null   object
#  32  Score                                          8096 non-null   float64
#  33  Field Values                                   8096 non-null   float64
#  34  Mean                                           4788 non-null   float64
#  35  Question Label                                 8115 non-null   object
#  36  Sluttekst                                      7737 non-null   object
#  37  Spm Formulering                                7737 non-null   object
#  38  Topic Label                                    8115 non-null   object
#  39  Type                                           8096 non-null   object
#  40  Year                                           8115 non-null   int64
#  41  isPsychological                                8115 non-null   object
# dtypes: float64(21), int64(3), object(18)
# memory usage: 2.6+ MB
#         Field Values Index                                      Ordforklaring  \
# count              8096.00                                               7737
# unique                 nan                                                104
# top                    nan  Spørgsmål: Hvor ofte kan man stole på de udmel...
# freq                   nan                                                 76
# mean                 56.18                                                NaN
# std                  24.89                                                NaN
# min                   0.00                                                NaN
# 25%                  38.77                                                NaN
# 50%                  56.76                                                NaN
# 75%                  74.98                                                NaN
# max                 100.00                                                NaN
#
#          Akse  Farveskala  Field Values Index (Fixed)  \
# count    8096     8096.00                     8115.00
# unique      3         nan                         nan
# top     Score         nan                         nan
# freq     4712         nan                         nan
# mean      NaN       -2.28                       58.50
# std       NaN       21.80                       13.43
# min       NaN      -86.47                       17.89
# 25%       NaN      -15.75                       50.00
# 50%       NaN       -0.16                       57.24
# 75%       NaN       12.43                       65.96
# max       NaN       82.11                       86.47
#
#        Navigation - Arbejdsmiljøprofiler  \
# count                               8115
# unique                                 1
# top                 Arbejdsmiljøprofiler
# freq                                8115
# mean                                 NaN
# std                                  NaN
# min                                  NaN
# 25%                                  NaN
# 50%                                  NaN
# 75%                                  NaN
# max                                  NaN
#
#         Score (Indekseret score) (gennemsnit)  \
# count                                 8115.00
# unique                                    nan
# top                                       nan
# freq                                      nan
# mean                                    47.66
# std                                     25.69
# min                                      3.56
# 25%                                     21.31
# 50%                                     56.13
# 75%                                     70.93
# max                                     86.51
#
#         Score (Indekseret score) (gennemsnit) (label)  Score (Total) (Fixed)  \
# count                                         8115.00                8115.00
# unique                                            nan                    nan
# top                                               nan                    nan
# freq                                              nan                    nan
# mean                                            13.82                  -5.99
# std                                             18.23                  22.08
# min                                              1.20                 -86.51
# 25%                                              3.17                 -12.82
# 50%                                              3.96                  -2.58
# 75%                                             17.03                   3.70
# max                                             86.51                  78.64
#
#         Gennemsnit  Score (Indekseret score)  Score (Total)  Antpct  Antpers  \
# count       109.00                   8096.00         109.00 3308.00  8115.00
# unique         nan                       nan            nan     nan      nan
# top            nan                       nan            nan     nan      nan
# freq           nan                       nan            nan     nan      nan
# mean         13.77                     48.03          -6.08   26.27   947.84
# std          18.24                     26.54          22.06   23.36  4054.86
# min           1.20                      0.00         -86.51    0.00    21.00
# 25%           3.23                     22.14         -12.82    7.92   188.00
# 50%           4.02                     56.22          -2.61   17.93   273.00
# 75%          17.03                     69.91           3.67   40.07   599.50
# max          86.51                    100.00          78.64  100.00 37664.00
#
#                                    Group  Hoej Score Godt  Kategori10  \
# count                               8115          8115.00      152.00
# unique                                76              nan         nan
# top     Speditører og ekspeditører m.fl.              nan         nan
# freq                                 109              nan         nan
# mean                                 NaN             0.44        9.00
# std                                  NaN             0.50        0.00
# min                                  NaN             0.00        9.00
# 25%                                  NaN             0.00        9.00
# 50%                                  NaN             0.00        9.00
# 75%                                  NaN             1.00        9.00
# max                                  NaN             1.00        9.00
#
#                      Kategori11  Kategori12  Kategori13  Kategori14  \
# count                       152        0.00        0.00        0.00
# unique                        2         nan         nan         nan
# top     10 ~ Bedste arbejdsevne         nan         nan         nan
# freq                         76         nan         nan         nan
# mean                        NaN         nan         nan         nan
# std                         NaN         nan         nan         nan
# min                         NaN         nan         nan         nan
# 25%                         NaN         nan         nan         nan
# 50%                         NaN         nan         nan         nan
# 75%                         NaN         nan         nan         nan
# max                         NaN         nan         nan         nan
#
#         Kategori15   Kategori1     Kategori2       Kategori3 Kategori4  \
# count         0.00        7737          7281            7129      6602
# unique         nan          26            22              20        19
# top            nan   1. Aldrig   2. Sjældent   3. Sommetider   4. Ofte
# freq           nan        2432          2432            2584      2432
# mean           nan         NaN           NaN             NaN       NaN
# std            nan         NaN           NaN             NaN       NaN
# min            nan         NaN           NaN             NaN       NaN
# 25%            nan         NaN           NaN             NaN       NaN
# 50%            nan         NaN           NaN             NaN       NaN
# 75%            nan         NaN           NaN             NaN       NaN
# max            nan         NaN           NaN             NaN       NaN
#
#         Kategori5          Kategori6  Kategori7  Kategori8  Kategori9  \
# count        6530               2265     152.00     152.00     152.00
# unique         17                  5        nan        nan        nan
# top      5. Altid  Næsten hele tiden        nan        nan        nan
# freq         2432               1149        nan        nan        nan
# mean          NaN                NaN       6.00       7.00       8.00
# std           NaN                NaN       0.00       0.00       0.00
# min           NaN                NaN       6.00       7.00       8.00
# 25%           NaN                NaN       6.00       7.00       8.00
# 50%           NaN                NaN       6.00       7.00       8.00
# 75%           NaN                NaN       6.00       7.00       8.00
# max           NaN                NaN       6.00       7.00       8.00
#
#        Main Group   Score  Field Values    Mean          Question Label  \
# count        8115 8096.00       8096.00 4788.00                    8115
# unique          1     nan           nan     nan                     109
# top           Job     nan           nan     nan  Kollegial anerkendelse
# freq         8115     nan           nan     nan                      76
# mean          NaN   14.31         -6.42    6.05                     NaN
# std           NaN   20.35         24.04   12.50                     NaN
# min           NaN    0.00       -100.00    0.63                     NaN
# 25%           NaN    3.08         -9.84    2.91                     NaN
# 50%           NaN    3.86         -1.81    3.33                     NaN
# 75%           NaN   15.80          3.60    3.84                     NaN
# max           NaN  100.00         83.28   83.28                     NaN
#
#                                                 Sluttekst  \
# count                                                7737
# unique                                                 55
# top     I resultaterne præsenteres den gennemsnitlige ...
# freq                                                 1976
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                           Spm Formulering       Topic Label  \
# count                                                7737              8115
# unique                                                102                37
# top     Hvor stor en del af din arbejdstid går eller s...  Ledelseskvalitet
# freq                                                  148               684
# mean                                                  NaN               NaN
# std                                                   NaN               NaN
# min                                                   NaN               NaN
# 25%                                                   NaN               NaN
# 50%                                                   NaN               NaN
# 75%                                                   NaN               NaN
# max                                                   NaN               NaN
#
#         Type    Year  isPsychological
# count   8096 8115.00          8115.00
# unique     2     nan             3.00
# top     kont     nan             1.00
# freq    4788     nan          4455.00
# mean     NaN 2018.00              nan
# std      NaN    0.00              nan
# min      NaN 2018.00              nan
# 25%      NaN 2018.00              nan
# 50%      NaN 2018.00              nan
# 75%      NaN 2018.00              nan
# max      NaN 2018.00              nan

# %%
# ----- Visualize data -----

# Get number of respondents per "group"
count = df_brancher.groupby(["Group"])["Antpers"].max()
count = count.drop(labels="Total") # <- Remove "Total" from the groups

# Make into dataframe for visualizations purposes, and sort by number of respondents
count = pd.DataFrame(count).sort_values("Antpers", ascending=False)

# Plot number of respondents per "Group"
plt.subplots(figsize=(6, 15))

sns.set_color_codes("pastel")
sns.barplot(x=count.Antpers, y=count.index, data=count, color="b")

# %% [markdown]
# ### Finding 1

# %%
df_brancher.groupby(["Group"])["Score (Indekseret score)"].mean().sort_values(ascending=False)
# Out:
# Group
# Frisører og kosmetologer                         54.29
# Slagtere og bagere                               52.89
# Gartnere og landmænd                             51.85
# Murere, VVSīere m.fl.                            51.55
# Malere                                           51.40
# Tømrere og snedkere                              50.70
# Nærings- og nydelsesmiddelindustrimedarbejdere   50.07
# Produktionsmedarbejdere                          50.00
# SOSUīer                                          49.95
# Servicefag i øvrigt                              49.76
# Køkkenmedhjælpere                                49.66
# Farmaceuter, tandlæger og dyrlæger               49.61
# Bygge- og anlægsarbejdere                        49.61
# Smede                                            49.60
# Mekanikere                                       49.48
# Kokke og tjenere                                 49.46
# Montører                                         49.33
# Samfundsvidenskabelige akademikere               49.30
# Maskinoperatører m.fl.                           49.19
# Dagplejere og børneomsorgsbeskæftigede           49.15
# Manuelt arbejde uden nærmere angivelse           49.09
# Jord- og betonarbejdere                          49.04
# Portører m.fl.                                   49.02
# Militærpersonale                                 48.88
# Passagerservicemedarbejdere                      48.86
# Laboranter                                       48.83
# Elektrikere                                      48.82
# Læger                                            48.64
# Rengøringsassistenter                            48.52
# Naturvidenskabelige akademikere                  48.48
# Sygeplejersker                                   48.43
# Maskinførere                                     48.41
# Specialpædagoger                                 48.31
# Brandmænd, reddere og sikkerhedsvagter           48.27
# Bogholdere                                       48.19
# Psykologer                                       48.17
# Journalister                                     48.08
# Lastbilchauffører                                48.06
# Lager- og transportarbejdere                     48.04
# Farmakonomer og bioanalytikere                   47.97
# Tekniske tegnere                                 47.97
# Pædagoger                                        47.88
# Klinikassistenter                                47.87
# Told- og skattemedarbejdere                      47.86
# Pædagogmedhjælpere                               47.72
# Regnskabsmedarbejdere                            47.51
# Præcisionshåndværkere                            47.46
# Sundhedsarbejdere uden nærmere angivelse         47.44
# Bibliotekarer og beskæftigede med kultur         47.31
# Fysio- og ergoterapeuter                         47.25
# Uoplyst                                          47.06
# Bude og kurerer                                  47.06
# Kasseassistenter                                 46.97
# Total                                            46.92
# Direktions-, læge-, og advokatsekretærer         46.67
# Socialrådgivere                                  46.58
# Ejendoms- og rengøringsinspektører               46.58
# Gymnasielærere                                   46.51
# Butikssælgere                                    46.48
# Revisorer, rådgivere og analytikere              46.46
# Ledere                                           46.43
# Speditører og ekspeditører m.fl.                 46.38
# IT-teknikere                                     46.37
# Politi og fængselsbetjente                       46.30
# Bus- og taxachauffører, lokoførere m.fl.         46.22
# Kundeinformationsarbejdere                       46.09
# Naturvidenskabelige teknikere                    46.04
# Jurister                                         45.71
# Ingeniører og arkitekter                         45.67
# Undervisere og forskere ved universiteter        45.47
# Specialundervisere                               45.45
# Salgs- og indkøbsagenter                         45.31
# Undervisere ved erhvervsskoler                   45.23
# Skolelærere                                      45.16
# IT-konsulenter                                   44.90
# Kontormedarbejdere og sekretærer                 44.59
# Name: Score (Indekseret score), dtype: float64

# %% [markdown]
# ### Finding 2

# %%
# Create dictionary 
isPsychological = dict((element,0) for element in df_brancher["Topic Label"].unique())

# Manually label psychological types
isPsychological["Angstsymptomer"] = 1
isPsychological["Arbejdsevne"] = "Return"
isPsychological["Arbejdspladsens prioritering af arbejdsmiljø"] = "Undefineable"
isPsychological["Arbejdsrelateret sygdom"] = "Undefineable"
isPsychological["Arbejdstid"] = "Undefineable"
isPsychological["Depressive symptomer"] = 1
isPsychological["Egen indsats for arbejdsmiljø"] = 1
isPsychological["Engagement og mening i arbejdet"] = 1
isPsychological["Følelsesmæssige krav"] = 1
isPsychological["Helbred"] = "Undefineable"
isPsychological["Indflydelse"] = "Undefineable"
isPsychological["Kollegial støtte og samarbejde"] = 1
isPsychological["Jobusikkerhed"] = 1
isPsychological["Kollegial anerkendelse"] = 1
isPsychological["Konflikter mellem arbejde og privatliv"] = 1
isPsychological["Kvantitative krav og grænseløshed"] = 1
isPsychological["Ledelseskvalitet"] = 1
isPsychological["Mentalt helbred"] = 1
isPsychological["Negative oplevelser"] = 1
isPsychological["Nyansatte"] = "Undefineable"
isPsychological["Retfærdighed"] = 1
isPsychological["Rolleklarhed"] = 1
isPsychological["Rummelighed"] = 1
isPsychological["Sundhedsfremmetilbud"] = "Undefineable"
isPsychological["Træthed og søvnproblemer"] = 1
isPsychological["Uoverskuelighed og stress"] = 1
isPsychological["Vold og trusler"] = "Return"
isPsychological
# Out:
# {'Kvantitative krav og grænseløshed': 1,
#  'Følelsesmæssige krav': 1,
#  'Konflikter mellem arbejde og privatliv': 1,
#  'Træthed og søvnproblemer': 1,
#  'Jobusikkerhed': 1,
#  'Ledelseskvalitet': 1,
#  'Rolleklarhed': 1,
#  'Retfærdighed': 1,
#  'Rummelighed': 1,
#  'Indflydelse': 'Undefineable',
#  'Kollegial støtte og samarbejde': 1,
#  'Kollegial anerkendelse': 1,
#  'Egen indsats for arbejdsmiljø': 1,
#  'Arbejdsevne': 'Return',
#  'Helbred': 'Undefineable',
#  'Engagement og mening i arbejdet': 1,
#  'Sikkerhed på arbejdspladsen': 0,
#  'Arbejdspladsens prioritering af arbejdsmiljø': 'Undefineable',
#  'Arbejdsrelateret sygdom': 'Undefineable',
#  'Smerter': 0,
#  'Arbejdstid': 'Undefineable',
#  'Negative oplevelser': 1,
#  'Vold og trusler': 'Return',
#  'Støj og vibrationer': 0,
#  'Støv, dampe og gasser': 0,
#  'Belastende arbejdsstillinger': 0,
#  'Hudpåvirkning og hudproblemer': 0,
#  'Løft, skub eller træk af byrder': 0,
#  'Uoverskuelighed og stress': 1,
#  'Ulykker': 0,
#  'Gående, stående og siddende arbejde': 0,
#  'Nyansatte': 'Undefineable',
#  'Depressive symptomer': 1,
#  'Angstsymptomer': 1,
#  'Sundhedsfremmetilbud': 'Undefineable',
#  'Mentalt helbred': 1,
#  'Fysisk hårdt arbejde': 0}

# %%
# Insert values into dataframe
df_brancher["isPsychological"] = 0

for key in isPsychological:
    df_brancher.loc[df_brancher["Topic Label"] == key, "isPsychological"] = isPsychological[key]
    
# Manually insert values for special cases
df_brancher.loc[df_brancher["Question Label"] == "Fysisk arbejdsevne", "isPsychological"] = 0
df_brancher.loc[df_brancher["Question Label"] == "Arbejdsevne", "isPsychological"] = "Undefineable"
df_brancher.loc[df_brancher["Question Label"] == "Psykisk arbejdsevne", "isPsychological"] = 1
df_brancher.loc[df_brancher["Question Label"] == "Fysisk vold", "isPsychological"] = 0
df_brancher.loc[df_brancher["Question Label"] == "Trusler", "isPsychological"] = 1

# %%
# Udregn ny score
dc = df_brancher.groupby(["Group", "isPsychological"])["Score (Indekseret score)"].mean().unstack()

# Rename columns
dc = dc.rename(columns={0: "Fysical", 1: "Psychological"})

# Add count
dc['Count'] = df_brancher.groupby(["Group"])["Antpers"].max()

dc.drop(columns=['Undefineable'])
# Out:
# isPsychological                                 Fysical  Psychological  Count
# Group
# Bibliotekarer og beskæftigede med kultur          28.31          58.48    228
# Bogholdere                                        29.25          57.61    394
# Brandmænd, reddere og sikkerhedsvagter            32.89          57.03    192
# Bude og kurerer                                   36.12          56.33    186
# Bus- og taxachauffører, lokoførere m.fl.          30.51          55.85    289
# Butikssælgere                                     31.43          57.79    992
# Bygge- og anlægsarbejdere                         40.68          57.36    280
# Dagplejere og børneomsorgsbeskæftigede            35.84          57.68    311
# Direktions-, læge-, og advokatsekretærer          26.73          57.88    668
# Ejendoms- og rengøringsinspektører                32.04          57.14    373
# Elektrikere                                       39.11          57.45    380
# Farmaceuter, tandlæger og dyrlæger                29.52          60.63    172
# Farmakonomer og bioanalytikere                    33.53          57.96    267
# Frisører og kosmetologer                          46.85          62.78     37
# Fysio- og ergoterapeuter                          27.54          58.93    363
# Gartnere og landmænd                              44.86          59.51    144
# Gymnasielærere                                    26.22          58.04    359
# IT-konsulenter                                    21.96          58.26    949
# IT-teknikere                                      26.43          57.08    273
# Ingeniører og arkitekter                          23.12          58.19   1129
# Jord- og betonarbejdere                           41.30          56.54    198
# Journalister                                      29.42          57.69    196
# Jurister                                          23.24          58.37    509
# Kasseassistenter                                  35.49          56.89    319
# Klinikassistenter                                 33.65          57.40    146
# Kokke og tjenere                                  35.77          59.17    238
# Kontormedarbejdere og sekretærer                  23.51          57.33   2110
# Kundeinformationsarbejdere                        26.37          57.52    277
# Køkkenmedhjælpere                                 41.08          57.82    314
# Laboranter                                        31.24          59.06    232
# Lager- og transportarbejdere                      37.22          56.39    409
# Lastbilchauffører                                 35.89          57.02    395
# Ledere                                            23.23          60.08   1948
# Læger                                             29.26          60.54    305
# Malere                                            47.03          58.38    128
# Manuelt arbejde uden nærmere angivelse            38.96          57.24    108
# Maskinførere                                      38.23          56.19    116
# Maskinoperatører m.fl.                            39.14          56.16    773
# Mekanikere                                        44.72          56.22    275
# Militærpersonale                                  32.02          57.53    262
# Montører                                          37.42          58.28    171
# Murere, VVSīere m.fl.                             50.79          56.79    311
# Naturvidenskabelige akademikere                   26.65          58.74    182
# Naturvidenskabelige teknikere                     26.72          57.57    675
# Nærings- og nydelsesmiddelindustrimedarbejdere    41.32          56.38    269
# Passagerservicemedarbejdere                       37.35          56.61     90
# Politi og fængselsbetjente                        27.16          57.70    214
# Portører m.fl.                                    35.51          58.81    253
# Produktionsmedarbejdere                           41.32          57.73    244
# Præcisionshåndværkere                             37.30          55.48     73
# Psykologer                                        27.22          59.42    143
# Pædagoger                                         33.86          59.08   1261
# Pædagogmedhjælpere                                35.10          58.25    541
# Regnskabsmedarbejdere                             28.56          57.29    619
# Rengøringsassistenter                             38.57          57.34    745
# Revisorer, rådgivere og analytikere               23.21          58.47   1357
# SOSUīer                                           37.32          59.49   1793
# Salgs- og indkøbsagenter                          23.52          58.01    847
# Samfundsvidenskabelige akademikere                28.42          60.42    217
# Servicefag i øvrigt                               35.56          59.32     42
# Skolelærere                                       26.15          58.58   1526
# Slagtere og bagere                                44.15          58.91     78
# Smede                                             43.99          56.10    587
# Socialrådgivere                                   24.98          59.21    426
# Specialpædagoger                                  31.06          59.58    612
# Specialundervisere                                25.29          59.04    269
# Speditører og ekspeditører m.fl.                  30.48          56.66    572
# Sundhedsarbejdere uden nærmere angivelse          30.74          58.45    173
# Sygeplejersker                                    32.24          59.43   1310
# Tekniske tegnere                                  29.13          57.81    139
# Told- og skattemedarbejdere                       29.57          57.88    220
# Total                                             30.56          57.96  37664
# Tømrere og snedkere                               49.71          55.86    273
# Undervisere og forskere ved universiteter         23.35          59.30    650
# Undervisere ved erhvervsskoler                    25.71          58.20    262
# Uoplyst                                           31.17          58.49   3286

# %%
# Hvor præcis er .max() metoden?
# Svar:
dc.Count.sum()-37664
# Out:
# 37674

# %%
import seaborn as sns
import matplotlib.pyplot as plt
#sns.set_theme(style="whitegrid")
#plt.figure(figsize=(60, 60))

cmap = sns.cubehelix_palette(rot=-.4, as_cmap=True)
g = sns.relplot(data=dc,
                x='Fysical', 
                y='Psychological',
                hue='Fysical',
                size="Count",
                palette=cmap,
                sizes=(20, 500))

for x, y, i in zip(dc['Fysical'], dc['Psychological'], dc.index):
     plt.text(x = x+.2,
              y = y-.03,
              s = i, 
              color = 'purple',
              size=4)
g.savefig("output.png", dpi = 300)
#sns.load_dataset("planets")

# %%
dc2 = df_brancher.groupby(["Group", "isPsychological"])["Score (Indekseret score)"].mean().unstack()
dc2
#sns.catplot(x=dc2.index, y=dc2.isPsychological, kind="bar", data=dc2)

# %%
dc2

# %%
df_brancher.isPsychological.unique()

# %%
df_brancher.iloc[5000:5498]

# %%
a = list(df_brancher["Topic Label"].unique())
a.sort()
a

# %%
df_brancher[df_brancher["Topic Label"] == "Helbred"]

# %%
df_brancher["Question Label"].unique()

# %% [markdown]
# ### Descriptive Statistics - "Personer og Køn"

# %%
# Show data
df_personer.head(3)

# Get descriptive statistics
#df_personer.describe(include='all')

# Get general info about the dataframe
#df_personer.info()
# Out:
#        Question Label     Topic Label  Year   Akse  \
# 0  Symptomer på angst  Angstsymptomer  2018  Score
# 1  Symptomer på angst  Angstsymptomer  2018  Score
# 2  Symptomer på angst  Angstsymptomer  2018  Score
#
#                                        Ordforklaring  Antpers  Farveskala  \
# 0  Spørgsmål: I de sidste fire uger, hvor meget h...     5080       38.85
# 1  Spørgsmål: I de sidste fire uger, hvor meget h...     5367       29.43
# 2  Spørgsmål: I de sidste fire uger, hvor meget h...     3496       18.44
#
#    Gennemsnit  Score (Indekseret score) (gennemsnit) (label)  \
# 0         nan                                            nan
# 1         nan                                            nan
# 2         nan                                            nan
#
#    Score (Indekseret score) (gennemsnit)  Score (Indekseret score)  Score  \
# 0                                    nan                     18.22   0.91
# 1                                    nan                     19.64   0.98
# 2                                    nan                     21.29   1.06
#
#     Køn Aldersgruppe isPsychological
# 0  Mænd   55 - 64 år               1
# 1  Mænd   45 - 54 år               1
# 2  Mænd   35 - 44 år               1

# %%
# Split "Group" in two columns
df_personer[['Køn', 'Aldersgruppe']] = df_personer.Group.str.split(pat=',', expand=True)
df_personer = df_personer.drop(columns=['Group'])
df_personer.head(3)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-74-1d664db3771e> in <module>
#       1 # Split "Group" in two columns
# ----> 2 df_personer[['Køn', 'Aldersgruppe']] = df_personer.Group.str.split(pat=',', expand=True)
#       3 df_personer = df_personer.drop(columns=['Group'])
#       4 df_personer.head(3)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'Group'

# %%
# Insert values into dataframe
df_personer["isPsychological"] = 0

for key in isPsychological:
    df_personer.loc[df_personer["Topic Label"] == key, "isPsychological"] = isPsychological[key]
    
# Manually insert values for special cases
df_personer.loc[df_personer["Question Label"] == "Fysisk arbejdsevne", "isPsychological"] = 0
df_personer.loc[df_personer["Question Label"] == "Arbejdsevne", "isPsychological"] = "Undefineable"
df_personer.loc[df_personer["Question Label"] == "Psykisk arbejdsevne", "isPsychological"] = 1
df_personer.loc[df_personer["Question Label"] == "Fysisk vold", "isPsychological"] = 0
df_personer.loc[df_personer["Question Label"] == "Trusler", "isPsychological"] = 1

# %%
df_personer.head(3)
# Out:
#        Question Label     Topic Label  Year   Akse  \
# 0  Symptomer på angst  Angstsymptomer  2018  Score
# 1  Symptomer på angst  Angstsymptomer  2018  Score
# 2  Symptomer på angst  Angstsymptomer  2018  Score
#
#                                        Ordforklaring  Antpers  Farveskala  \
# 0  Spørgsmål: I de sidste fire uger, hvor meget h...     5080       38.85
# 1  Spørgsmål: I de sidste fire uger, hvor meget h...     5367       29.43
# 2  Spørgsmål: I de sidste fire uger, hvor meget h...     3496       18.44
#
#    Gennemsnit  Score (Indekseret score) (gennemsnit) (label)  \
# 0         nan                                            nan
# 1         nan                                            nan
# 2         nan                                            nan
#
#    Score (Indekseret score) (gennemsnit)  Score (Indekseret score)  Score  \
# 0                                    nan                     18.22   0.91
# 1                                    nan                     19.64   0.98
# 2                                    nan                     21.29   1.06
#
#     Køn Aldersgruppe isPsychological
# 0  Mænd   55 - 64 år               1
# 1  Mænd   45 - 54 år               1
# 2  Mænd   35 - 44 år               1

# %%
dq = df_personer.groupby(["Køn", "Aldersgruppe"])["Antpers"].max()#.unstack(level=0)
dq = dq.reset_index()

# %%
import seaborn as sns
g = sns.barplot(
    data=dq, x='Aldersgruppe', y='Antpers', hue='Køn')#, color="b")
